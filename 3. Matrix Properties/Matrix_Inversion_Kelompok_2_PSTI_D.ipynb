# %% [markdown]
# ### Matrix Inversion

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# buat matrix X ukuran 2x2 menggunakan numpy
X = np.array([[8, 3], [-5, -9]])
X
# Out:
# array([[ 8,  3],
#        [-5, -9]])

# %%
# buat invers dari matrix X dan beri nama Xinv menggunakan numpy
Xinv = np.linalg.inv(X)
Xinv
# Out:
# array([[ 0.15789474,  0.05263158],
#        [-0.0877193 , -0.14035088]])

# %%
# kalikan X dengan Xinv menggunakan numpy
np.dot(Xinv, X)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %% [markdown]
# Penyelesaian menggunakan PyTorch dan TensorFlow:

# %%
# selesaikan persamaan berikut menggunakan numpy, tensorflow dan pytorch
import numpy as np
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

# %%
# penyelesaian menggunakan numpy

# buat matrix X ukuran 2x2 menggunakan numpy
X = np.array([[4, 2], [-5, -3]])
X
# Out:
# array([[ 4,  2],
#        [-5, -3]])

# %%
# buat invers dari matrix X dan beri nama Xinv menggunakan numpy
Xinv = np.linalg.inv(X)
Xinv
# Out:
# array([[ 1.5,  1. ],
#        [-2.5, -2. ]])

# %%
# kalikan X dengan Xinv menggunakan numpy
np.dot(Xinv, X)
# Out:
# array([[1.00000000e+00, 3.33066907e-16],
#        [0.00000000e+00, 1.00000000e+00]])

# %%
# buat matrix y menggunakan numpy
y = np.array([4, -7])
y
# Out:
# array([ 4, -7])

# %%
# cari nilai w
w = np.dot(Xinv, y)
w
# Out:
# array([-1.,  4.])

# %%
# penyelesaian menggunakan TensorFlow
X_inv_tf = tf.linalg.inv(tf.Variable([[4, 2], [-5, -3.]])) # also float
X_inv_tf
w_tf = tf.linalg.matvec(X_inv_tf, y_tf)
w_tf
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([-0.9999995,  3.999999 ], dtype=float32)>

# %%
# penyelesaian menggunakan PyTorch
X_inv_torch = torch.inverse(torch.tensor([[4, 2], [-5, -3.]])) # float type
X_inv_torch
w_torch = torch.matmul(X_inv_torch, y_torch)
w_torch
# Out:
# tensor([-1.,  4.])
