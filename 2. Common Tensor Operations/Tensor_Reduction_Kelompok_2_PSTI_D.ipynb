# %% [markdown]
# Soal Nomor 1

# %%
# buat matrix X dengan ukuran 2x3 menggunakan numpy

# %%
import numpy as np

# %%
X = np.array([[17, 5, 10], [13, 9, 2]])
X
# Out:
# array([[17,  5, 10],
#        [13,  9,  2]])

# %%
# hitung berapa hasil penjumlahan elemen matrix X dengan fungsi sum
X.sum()
# Out:
# np.int64(56)

# %%
# buat matrix X_tf dengan ukuran 2x3 menggunakan tensorflow

# %%
import tensorflow as tf

# %%
X_tf = tf.Variable([[17, 5, 10], [13, 9, 2]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[17,  5, 10],
#        [13,  9,  2]], dtype=int32)>

# %% [markdown]
# Soal Nomor 2

# %%
# hitung hasil penjumlahan seluruh elemen matrix X
X.sum()
# Out:
# np.int64(56)

# %%
# hitung hasil penjumlahan seluruh elemen matrix X_pt

# %%
import torch

# %%
X_pt = torch.tensor([[17, 5, 10], [13, 9, 2]])
X_pt
# Out:
# tensor([[17,  5, 10],
#         [13,  9,  2]])

# %%
torch.sum(X_pt)
# Out:
# tensor(56)

# %%
# hitung hasil penjumlahan seluruh elemen matrix X_tf
tf.reduce_sum(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=56>

# %% [markdown]
# Soal Nomor 3

# %%
# hitung hasil penjumlahan matrix X berdasarkan row nya
X.sum(axis=1)
# Out:
# array([32, 24])

# %%
# hitung hasil penjumlahan matrix X_pt berdasarkan row nya
torch.sum(X_pt, 1)
# Out:
# tensor([32, 24])

# %%
# hitung hasil penjumlahan matrix X_tf berdasarkan row nya
tf.reduce_sum(X_tf, 1)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([32, 24], dtype=int32)>

# %% [markdown]
# Soal Nomor 4

# %%
# hitung hasil penjumlahan matrix X berdasarkan kolom nya
X.sum(axis=0)
# Out:
# array([30, 14, 12])

# %%
# hitung hasil penjumlahan matrix X_pt berdasarkan kolom nya
torch.sum(X_pt, 0)
# Out:
# tensor([30, 14, 12])

# %%
# hitung hasil penjumlahan matrix X_tf berdasarkan kolom nya
tf.reduce_sum(X_tf, 0)
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([30, 14, 12], dtype=int32)>

# %% [markdown]
# Soal Nomor 5

# %%
# hitung nilai minimal dari matrix X, X_pt dan X_tf
X.min()
# Out:
# np.int64(2)

# %%
X_pt.min()
# Out:
# tensor(2)

# %%
tf.reduce_min(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>

# %%
# hitung nilai maksimal dari matrix X, X_pt dan X_tf
X.max()
# Out:
# np.int64(17)

# %%
X_pt.max()
# Out:
# tensor(17)

# %%
tf.reduce_max(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=17>

# %%
# hitung nilai rata-rata dari matrix X, X_pt dan X_tf
X.mean()
# Out:
# np.float64(9.333333333333334)

# %%
X_pt.float().mean()
# Out:
# tensor(9.3333)

# %%
tf.reduce_mean(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=9>

# %% [markdown]
# Soal Nomor 6

# %%
# hitung hasil perkalian seluruh elemen matrix X
X.prod()
# Out:
# np.int64(198900)

# %%
# hitung hasil perkalian seluruh elemen matrix X_pt
X_pt.prod()
# Out:
# tensor(198900)

# %%
# hitung hasil perkalian seluruh elemen matrix X_tf
tf.reduce_prod(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=198900>
